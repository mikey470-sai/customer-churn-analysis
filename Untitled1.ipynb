# %%
import pandas as pd

df = pd.read_csv("teleco_csv.csv")
print(df.head())

# %%
import os
print(os.listdir())  # shows all files in current folder
# Out:
# ['.vimrc', '.jupyter', 'view?usp=sharing', '.ipynb_checkpoints', '.anaconda', 'Untitled1.ipynb', '.pythonstartup.py', '.local', '.npm', '.gitconfig', 'Untitled.ipynb', 'anaconda_projects', '.virtualenvs', '.profile', '.bashrc', '.ipython', 'telco_csv.csv', '.cache', '.config', 'README.ipynb']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("telecom_churn_csv.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
print(df['Churn'].value_counts())
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df['TenureGroup'] = pd.cut(df['tenure'],
                           bins=[0, 3, 12, 24, 48, 60, 72],
                           labels=['0-3','4-12','13-24','25-48','49-60','61-72'])

# %%
df['ContractType'] = df['Contract'].replace({
    'Month-to-month': 'Monthly',
    'One year': 'Annual',
    'Two year': 'Biennial'
})

print("\n--- Added TenureGroup & ContractType ---")
print(df[['tenure','TenureGroup','Contract','ContractType']].head())
# Out:
# --- Added TenureGroup & ContractType ---
#    tenure TenureGroup        Contract ContractType
# 0       1         0-3  Month-to-month      Monthly
# 1      34       25-48        One year       Annual
# 2       2         0-3  Month-to-month      Monthly
# 3      45       25-48        One year       Annual
# 4       2         0-3  Month-to-month      Monthly

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(6,4))
sns.countplot(x='Churn', data=df)
plt.title("Churn Count")
plt.show()

plt.figure(figsize=(8,5))
sns.countplot(x='TenureGroup', hue='Churn', data=df)
plt.title("Churn by Tenure Group")
plt.show()

plt.figure(figsize=(6,4))
sns.countplot(x='ContractType', hue='Churn', data=df)
plt.title("Churn by Contract Type")
plt.show()

plt.figure(figsize=(6,4))
sns.boxplot(x='Churn', y='MonthlyCharges', data=df)
plt.title("Monthly Charges vs Churn")
plt.show()
# Out:
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
plt.hist(df['MonthlyCharges'], bins=30, color='skyblue', edgecolor='black')
plt.title("Distribution of Monthly Charges")
plt.xlabel("Monthly Charges")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
churn_pct = df['Churn'].value_counts(normalize=True) * 100
print("\n--- Churn Percentage ---")
print(churn_pct)
# Out:
# --- Churn Percentage ---
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
churn_group = df.groupby(['ContractType','TenureGroup'])['Churn'].value_counts(normalize=True) * 100
print("\n--- Churn % by Contract & Tenure ---")
print(churn_group)
# Out:
# --- Churn % by Contract & Tenure ---
# ContractType  TenureGroup  Churn
# Annual        0-3          No        90.000000
#                            Yes       10.000000
#               4-12         No        89.320388
#                            Yes       10.679612
#               13-24        No        91.878173
#                            Yes        8.121827
#               25-48        No        89.382239
#                            Yes       10.617761
#               49-60        No        86.292835
#                            Yes       13.707165
#               61-72        No        87.859425
#                            Yes       12.140575
# Biennial      0-3          No       100.000000
#                            Yes        0.000000
#               4-12         No       100.000000
#                            Yes        0.000000
#               13-24        No       100.000000
#                            Yes        0.000000
# ...

# %%
monthly_churn = churn_group.loc['Monthly'].loc['0-3'].loc['Yes']
print(f"\n🚨 Key Insight: {monthly_churn:.2f}% of churned users are on Monthly Contracts with <3 month tenure.")
print("💡 Suggestion: Improve early engagement strategies to retain new customers.")
# Out:
# 🚨 Key Insight: 58.05% of churned users are on Monthly Contracts with <3 month tenure.
# 💡 Suggestion: Improve early engagement strategies to retain new customers.
